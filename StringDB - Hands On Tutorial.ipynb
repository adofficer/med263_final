# %% [markdown]
# # StringDB - A Biology Resource for Bioinformatics
#
#
# ## Today we will be walking through a tutorial on how to use StringDB to investigate biological relationships between groups of genes
# * As an example we will be generating a list of genes involved in smoking-associated lung cancer
# * The data we are using is from The Cancer Genome Atlas lung cancer cohorts of lung adenocarcinoma and lung squamous cell carcinoma
# * We will be identifying genes with large differences in median expression between smokers and non-smokers with lung cancer

# %%
import pandas as pd

# %%
expr = pd.read_csv("./tcga_selected_lung_expr.csv", index_col = 0)

# %%
expr.head()
# Out:
#              TCGA-49-4512  TCGA-55-8619  TCGA-75-6212  TCGA-97-A4M6  \
# Hugo_Symbol
# UBE2Q2P2          10.5919       12.1666       27.2807       11.4083
# HMGB1P1           71.9754       96.0280      108.6780       73.6311
# RNU12-2P           0.7686        0.0000        0.0000        1.3706
# SSX9P              0.0000        0.0000        0.0000        0.0000
# EZHIP              0.7686        0.0000        0.0000        0.4569
#
#              TCGA-50-6597  TCGA-69-7760  TCGA-55-6986  TCGA-55-8513  \
# Hugo_Symbol
# UBE2Q2P2           2.6202        6.0025        9.9855       31.6469
# HMGB1P1           58.1904       62.7920      107.8270       99.9036
# RNU12-2P           0.0000        0.6246        0.0000        0.7418
# SSX9P              0.0000        0.0000        0.0000        0.0000
# EZHIP             12.2526        0.0000        1.4535        2.9674
#
#              TCGA-75-5147  TCGA-55-A57B  ...  TCGA-55-8089  TCGA-99-AA5R  \
# Hugo_Symbol                              ...
# UBE2Q2P2           9.0652       35.6276  ...        5.2768       24.0879
# HMGB1P1          208.9270       84.3653  ...      142.8950       71.8784
# RNU12-2P           0.2949        0.7052  ...        0.8317        1.6287
# SSX9P              0.2949        3.1735  ...        0.0000        0.0000
# EZHIP              7.9623        0.0000  ...        0.4158        4.8860
#
#              TCGA-49-AARO  TCGA-55-8510  TCGA-55-7914  TCGA-64-1679  \
# Hugo_Symbol
# UBE2Q2P2          18.6740       12.4602        9.9950        7.9803
# HMGB1P1           79.6771      113.1580      164.5980       76.3349
# RNU12-2P           2.3061        0.6120        0.9995        0.2902
# SSX9P              0.0000        0.0000        0.0000        0.0000
# EZHIP              0.0000        1.8360        0.0000        2.3215
#
#              TCGA-55-8096  TCGA-91-6831  TCGA-38-4625  TCGA-75-7027
# Hugo_Symbol
# UBE2Q2P2          36.8980       16.9631        2.3768       17.5941
# HMGB1P1           83.8594      109.5430       87.8119      238.0020
# RNU12-2P           0.6237        0.7718        0.5632        0.2895
# SSX9P              0.0000        0.0000        0.0000        0.0000
# EZHIP              0.3118        0.7718        0.2816        0.0000
#
# [5 rows x 40 columns]

# %% [markdown]
# # Now we need to read in the clinical annotations
# * The column we are interested in is "tobacco_smoking_history"

# %%
clin_annot = pd.read_csv("./tcga_annot_selected.csv",
                         index_col = 0)

# %%
clin_annot.head()
# Out:
#                                   bcr_patient_uuid acronym  gender  \
# TCGA-49-4512  a1e65587-24c1-4b41-92a7-4e1f15fffd78    LUAD  FEMALE
# TCGA-55-8619  772324a5-5513-454d-ad6b-605798f69b73    LUAD  FEMALE
# TCGA-75-6212  23069f19-eba5-4ea5-ae7d-1ee4399ce7c1    LUAD  FEMALE
# TCGA-97-A4M6  31FF69B5-9E58-44DA-8326-BDFC7EE495C4    LUAD  FEMALE
# TCGA-50-6597  0d66bf6c-eed0-4726-bd5b-3bf6d610b4e0    LUAD  FEMALE
#
#              vital_status    days_to_birth     days_to_death  \
# TCGA-49-4512         Dead           -25502               905
# TCGA-55-8619        Alive           -26616  [Not Applicable]
# TCGA-75-6212         Dead  [Not Available]              1516
# TCGA-97-A4M6        Alive           -16764  [Not Applicable]
# TCGA-50-6597         Dead           -29195              1268
#
#              days_to_last_followup days_to_initial_pathologic_diagnosis  \
# TCGA-49-4512                   157                                    0
# TCGA-55-8619                   416                                    0
# TCGA-75-6212       [Not Available]                      [Not Available]
# TCGA-97-A4M6                   568                                    0
# TCGA-50-6597                  1015                                    0
#
#              age_at_initial_pathologic_diagnosis  icd_10  ...  \
# TCGA-49-4512                                  69   C34.2  ...
# TCGA-55-8619                                  72  C34.30  ...
# TCGA-75-6212                     [Not Available]   C34.3  ...
# TCGA-97-A4M6                                  45   C34.3  ...
# TCGA-50-6597                                  79   C34.3  ...
#
#                                               histological_type  \
# TCGA-49-4512  Lung Adenocarcinoma- Not Otherwise Specified (...
# TCGA-55-8619                       Mucinous (Colloid) Carcinoma
# TCGA-75-6212                 Lung Micropapillary Adenocarcinoma
# TCGA-97-A4M6                  Lung Adenocarcinoma Mixed Subtype
# TCGA-50-6597  Lung Adenocarcinoma- Not Otherwise Specified (...
#
#              tissue_source_site form_completion_date pathologic_T  \
# TCGA-49-4512                 49               8/9/11           T2
# TCGA-55-8619                 55              1/11/13           T3
# TCGA-75-6212                 75              7/21/11           T2
# TCGA-97-A4M6                 97               3/7/13          T1a
# TCGA-50-6597                 50              8/26/11           T2
#
#              pathologic_M        clinical_M pathologic_N system_version  \
# TCGA-49-4512           MX  [Not Applicable]           N2            6th
# TCGA-55-8619           MX  [Not Applicable]           N0            7th
# TCGA-75-6212           M0  [Not Applicable]           N1            6th
# TCGA-97-A4M6           M0  [Not Applicable]           N0            7th
# TCGA-50-6597           M0  [Not Applicable]           N0            6th
#
#              pathologic_stage tobacco_smoking_history
# TCGA-49-4512       Stage IIIA     Lifelong Non-smoker
# TCGA-55-8619        Stage IIB     Lifelong Non-smoker
# TCGA-75-6212        Stage IIB     Lifelong Non-smoker
# TCGA-97-A4M6         Stage IA     Lifelong Non-smoker
# TCGA-50-6597         Stage IB     Lifelong Non-smoker
#
# [5 rows x 37 columns]

# %%
clin_annot.tobacco_smoking_history.value_counts()
# Out:
# Current smoker         20
# Lifelong Non-smoker    20
# Name: tobacco_smoking_history, dtype: int64

# %%
curr_smokers = clin_annot.query("tobacco_smoking_history == 'Current smoker'").index
nonsmokers = clin_annot.query("tobacco_smoking_history == 'Lifelong Non-smoker'").index

# %% [markdown]
# # Now that we know which samples in the TCGA are smokers and which ones are lifelong non-smokers we want to identify genes that differ in median expression between these two groups

# %%
non_sub_curr_median_expr = expr.loc[:, nonsmokers].median(axis = 1) - expr.loc[:, curr_smokers].median(axis = 1)

# %% [markdown]
# # Now we extract the 20 genes that have higher expression in the non-smokers

# %%
# your function here to select
candidate_genes = non_sub_curr_median_expr.nlargest(20).index

print("\n".join(candidate_genes))
# Out:
# SFTPB
# CD74
# SLC34A2
# NAPSA
# PIGR
# B2M
# ADAM6
# SFTPA2
# SFTPC
# CTSD
# SFTPA1
# CEACAM6
# HLA-DRA
# MUC1
# AQP1
# SDC1
# ATP1A1
# C1orf116
# A2M
# VIM

# %% [markdown]
# # Finally we want to load these into StringDB
# * StringDB is a centralized information resource with manually and programmatically curated gene-gene relationships
# * It serves to identify connections between groups of genes
# * https://string-db.org/
